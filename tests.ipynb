# %%
import os
import subprocess
import json
import yaml
from pymatgen.io.vasp.inputs import Incar
from pymatgen.io.vasp.inputs import Poscar
from pymatgen.io.vasp.outputs import Vasprun

# %%
os.path.join(os.getcwd(),'workflow_scripts')
# Out:
# 'c:\\Users\\Suxuen Yew\\Desktop\\Github Repositories\\kestrel_files\\vasp_workflow\\workflow_scripts'

# %%
for root, dirs, files in os.walk(os.path.join(os.getcwd(),'workflow_scripts')):
    print(f"Root: {root.split(os.sep)[-1]}, Dirs: {dirs}, Files: {files}")
# Out:
# Root: workflow_scripts, Dirs: ['__pycache__'], Files: ['create_input_yaml.py', 'generate_vasp_inputs.py', 'poscar_paths_to_yaml.py', 'rerun_workflow.py', '__init__.py']
# Root: __pycache__, Dirs: [], Files: ['create_input_yaml.cpython-39.pyc', '__init__.cpython-39.pyc']
